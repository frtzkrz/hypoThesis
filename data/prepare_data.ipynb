# %%
import pandas as pd
import numpy as np

# %%
usz_data = pd.read_csv('usz.csv', header=[0,1,2])
umcg_data = pd.read_csv('umcg.csv', header=[0,1,2])
usz_data
# Out:
#     patient                                                        \
#           #
#          id                 institution     sex age diagnose_date
# 0         0  University Hospital Zurich    male  49    2013-03-13
# 1         1  University Hospital Zurich    male  53    2013-09-13
# 2         2  University Hospital Zurich    male  86    2013-09-27
# 3         3  University Hospital Zurich    male  71    2013-10-17
# 4         4  University Hospital Zurich    male  67    2013-09-16
# ..      ...                         ...     ...  ..           ...
# 360     360  University Hospital Zurich    male  69    2021-03-19
# 361     361  University Hospital Zurich    male  49    2021-08-24
# 362     362  University Hospital Zurich  female  42    2021-09-14
# 363     363  University Hospital Zurich    male  47    2021-11-04
# 364     364  University Hospital Zurich    male  77    2016-05-24
#
#                                                                          ...  \
# ...

# %%
prepared_usz = usz_data[usz_data['tumor', '1', 'location'] == 'hypopharynx']
prepared_umcg = umcg_data[umcg_data['tumor', '1', 'location'] == 'hypopharynx']

# %%
prepared_usz.to_csv('usz_hypopharynx.csv')
prepared_umcg.to_csv('umcg_hypopharynx.csv')
